# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.linalg import helmert

# %%
def closure(nd):
    """
    Performs the closure operation on a multi-dimensional array, setting the constant
    sum of each row to 1.
    """
    return nd / nd.sum(-1, keepdims=True)
    
def makeComposition(n, D):
    """
    Create a random composition drawn from normal distribution. Composition will be of 
    D-dimension size, and there will be n compositions returned.
    """
    return closure(np.array([[np.random.rand() for x in range(D)] for row in range(n)]))

def makeDirichletComposition(n, D, alphas=None):
    """
    Generate samples from a dirichlet distribution using an array of alpha distributions.
    """
    if alphas is None:
#         alphas = np.array([[1.4083006 , 1.2694913 , 0.44200626, 0.53662235, 0.7079339 ] for x in range(n)])
        alphas = 2 ** np.random.randint(1,D+1, size=(n, D))
#         alphas = [[x for x in range(1, D+1)] for row in range(n)] 
    else:
        alphas = np.array([alphas for x in range(n)])
    r = np.random.standard_gamma(alphas)
    return closure(r)

def clr(a):
    """
    Apply a centered log-ratio transformation to a ndarray.
    """
    arr = list(a)
    return np.array([np.array([np.log(x/(np.prod(row)**(1/len(row)))) for x in row]) for row in arr])

def clr_boxcox(a, p):
    """
    Apply a centered log-ratio transformation to a ndarray.
    """
    arr = list(a)
    return np.array([np.array([((x/(np.prod(row)**(1/len(row))))**p - 1) / p for x in row]) for row in arr])

def ilr(a):
    """
    The isometric logratio transformation function turns a given composition into an orthonormal
    basis in D-1 dimensions on the basis of a given variable (by default, the first column).
    """
    x = np.array(a)
    res = (((x.shape[1]-1) / (x.shape[1])) ** (1/2) * 
           np.log(x[:, 0].reshape((x.shape[0],1)) / 
                  (np.prod(x[:, 1:], axis=1).reshape((x.shape[0], 1))) ** 
                  (1/((x.shape[1]-1)))).reshape((x.shape[0],1)))

    i = 1
    while i < (x.shape[1] - 1):        
        res = np.concatenate((res, 
                              ((x.shape[1]-i-1) / (x.shape[1]-i)) ** (1/2) * 
                              np.log(x[:, i].reshape((x.shape[0],1)) / 
                                     (np.prod(x[:, i+1:], axis=1).reshape((x.shape[0], 1))) ** 
                                     (1/((x.shape[1]-i-1)))).reshape((x.shape[0],1))), axis=1)
        i+=1        
    return res

def ilr_boxcox(a, p):
    """
    The isometric logratio transformation function turns a given composition into an orthonormal
    basis in D-1 dimensions on the basis of a given variable (by default, the first column).
    
    This is the generalized form of ILR with parameter p. For p=0, this is just a log transform.
    """
#     x = (np.e ** (p * np.log(a)) - 1) / p
#     x = np.apply_along_axis(lambda val: (np.e ** (p * val) - 1) / p, axis=0, arr=x)
#     x -= x.mean(axis=1).reshape(x.shape[0], 1)
#     H = helmert(a.shape[1], full=False)
#     H = H.transpose() / np.array([[2 for x in range(a.shape[1]-1)] for row in range(a.shape[1])])**(1/2)
#     return np.matmul(x, H)

    x = np.log(a)
    # Box-cox transform if the value of p is non-zero
    if p != 0:
        x = (np.e**(p*x) - 1) / p
    # Now we recenter values
    x = x - np.mean(x, axis=1).reshape((x.shape[0], 1))
    # Generate a helmert matrix of k*(k-1) proportions
    H = helmert(x.shape[1])
    # Return the matrix multiplacation, rotated and reflected
    return np.matmul(x, np.transpose(H)) * (-1)


def plotCompositionPairs(data):
    """
    Make pair-wise plots of the features of an ndarray.
    """
    fig, axs = plt.subplots(data.shape[1], data.shape[1], figsize=(15,12))

    for i in range(data.shape[1]):
        for j in range(data.shape[1]):
            if i==j:
                axs[i,j].set_yticklabels([])
                axs[i,j].set_xticklabels([])
                axs[i,j].get_xaxis().set_ticks([])
                axs[i,j].get_yaxis().set_ticks([])
                continue
            ax = axs[i, j].hexbin(x=data[:, i], y=data[:, j], bins='log', gridsize=50, cmap='inferno')

    fig.colorbar(ax, ax=axs.ravel().tolist(), orientation='vertical', shrink=1/(data.shape[1]+.5))

# %%
n = 1264
D = 5
# data = makeComposition(n, D)
data = makeDirichletComposition(n, D, alphas=np.array([0.5592544 , 1.1543314 , 0.8324738 , 0.31532133, 0.8594416]))

# %%
plotCompositionPairs(data)

# %%
plotCompositionPairs(clr(data))

# %%
plotCompositionPairs(clr_boxcox(data, 0.25))

# %%
plotCompositionPairs(ilr(data))

# %%
plotCompositionPairs(ilr_boxcox(data, 0.282828))

# %%
plotCompositionPairs(ilr_boxcox(data, 0.404040))

# %% [markdown]
# # Find the ideal parameter p for ilr_boxcox

# %%
from scipy.spatial import distance
import pandas as pd

# %%
def get_dist_var(nd):
    """
    Function to find the average variance in point distance from the center of all points for
    a normalized set of points. Quantifies the spread of a set of points.
    """
    # First compute the normalized set of coordinates (normalized by axis, NOT by row)
    x = nd.swapaxes(0,1)
    maxim = x.max(axis=1).reshape(x.shape[0],1)
    norm_nd = (x / maxim).swapaxes(0,1)
    
    # Now find the central point of all coordinates, and return the average variance of all coordinates
    mu = norm_nd.mean(axis=0)
    return np.apply_along_axis(lambda x: distance.minkowski(x, mu), axis=1, arr=norm_nd).mean()


def get_dist_var2(nd):
    """
    Function to find the average variance in point distance from the center of all points for
    a normalized set of points. Quantifies the spread of a set of points.
    """
    # First compute the normalized set of coordinates (normalized by axis, NOT by row)
    x = nd.swapaxes(0,1)
    minim = x.min(axis=1).reshape(x.shape[0],1)
    maxim = x.max(axis=1).reshape(x.shape[0],1)
    norm_nd = np.nan_to_num(((x - minim) / (maxim - minim)).swapaxes(0,1))
    
    # Now find the central point of all coordinates, and return the average variance of all coordinates
    mu = norm_nd.mean(axis=0)
    res = np.apply_along_axis(lambda a: distance.minkowski(a, mu), axis=1, arr=norm_nd)
    return res.mean(), res.var()

# %%
def get_dist_var3(nd):
    """
    Function to find the average variance in point distance from the center of all points for
    a normalized set of points. Quantifies the spread of a set of points.
    """
    x = nd.swapaxes(0,1)
    minim = x.min(axis=1).reshape(x.shape[0],1)
    maxim = x.max(axis=1).reshape(x.shape[0],1)
    norm_nd = ((x - minim) / (maxim - minim)).swapaxes(0,1)
    
    # Now find the central point of all coordinates, and return the average variance of all coordinates
    mu = np.zeros(nd.shape[1])
    res = np.apply_along_axis(lambda a: distance.minkowski(a, mu), axis=1, arr=norm_nd)
    return res.mean(), res.var()

# %%
alphas = np.array([0.00152999, 0.00152999, 0.00152999, 0.00152999, 0.14685275,
       0.16239065, 0.00152999, 0.00152999, 0.00153001, 0.00152999,
       0.00152999, 0.22516693, 0.00152999, 0.00152999, 0.00152999,
       0.00154319, 0.00154322, 0.00154331, 0.00152999, 0.00152999,
       0.00154331, 0.00154316, 0.00152999, 0.00152999, 0.00152999,
       0.00152999, 0.00153702, 0.00152999, 0.07488254, 0.00152999,
       0.00152999, 0.00152999, 0.00152999, 0.00152999, 0.00152999,
       0.2500552 , 0.0015433 , 0.00154325, 0.00154333, 0.00152999,
       0.00152999, 0.00152999, 0.09105524, 0.00152999, 0.00152999,
       0.13544282, 0.00152999, 0.06458096, 0.1288257 , 0.00152999,
       0.00152999, 0.00152999, 0.05180332, 0.00421674, 0.0026171 ,
       0.00152999, 0.09561475, 0.00152999, 0.00152999, 0.00152999,
       0.00152999, 0.00152999, 0.00152999, 0.00152999, 0.11671677,
       0.00152999, 0.00153132, 0.00152999, 0.00154327, 0.00152999,
       0.00152999, 0.00152999, 0.00152999, 0.03871365, 0.00153   ,
       0.12830146, 0.00152999, 0.00152999, 0.00152999, 0.00152999,
       0.00152999, 0.00152999, 0.00152999, 0.00152999, 0.00152999,
       0.07007095, 0.00152999, 0.00152999, 0.00152999, 0.06065543,
       0.00152999, 0.09137592, 0.00152999, 0.00152999, 0.00152999,
       0.00152999, 0.07203128, 0.00152999, 0.00154277, 0.00152999,
       0.0837492 , 0.01270636, 0.00152999, 0.00152999, 0.00152999,
       0.0015433 , 0.09035783, 0.00152999, 0.01021307, 0.00152999,
       0.00152999, 0.00152999, 0.15077563, 0.0015433 , 0.00152999,
       0.17856388, 0.00152999, 0.00153176, 0.0040684 , 0.00152999,
       0.02589896, 0.00155664, 0.0376702 , 0.00152999, 0.00152999,
       0.00152999, 0.16392225, 0.00152999, 0.00152999, 0.13548195,
       0.00152999, 0.00152999, 0.00152999, 0.00152999, 0.01731897,
       0.00152999, 0.00152999, 0.00152999, 0.00152999, 0.24621549])

# %%
n = 10000
D = 560

data = makeDirichletComposition(n, D, alphas)

# %%
num = 100
space = np.linspace(0, 2, num)

res = pd.DataFrame(columns=['p', 'av_dist'])

for p in space:
    new_data = ilr_boxcox(data, p)
    ret = get_dist_var2(new_data)
    
    cov_mat = np.triu(np.cov(new_data, rowvar=False), k=1).flatten()
    cov_mat = cov_mat[cov_mat!=0]
    av_cov = cov_mat.mean()
    var_cov = cov_mat.var()
    
    res = res.append({'p':p, 
                      'av_dist': ret[0], 
                      'var_dist': ret[1], 
                      'av_cov': av_cov, 
                      'var_cov': var_cov}, ignore_index=True)
# Out:
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:77: RuntimeWarning: divide by zero encountered in log
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:82: RuntimeWarning: invalid value encountered in subtract
# /opt/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:86: RuntimeWarning: invalid value encountered in matmul

# %%
plt.plot(res.p, res.av_dist)
# plt.plot(res.p, res.var_dist**0.25)
# plt.plot(res.p, res.av_cov)
plt.xlabel("Parameter $p$")
plt.ylabel("Average normalized spread")
plt.title("Plot of average spread for parameter $p$")
plt.grid(False);

# %%
res.sort_values('av_dist', ascending=False).head()
# Out:
#           p   av_dist    av_cov   var_cov  var_dist
# 1  0.020202  4.022820 -0.009358  0.498529  0.061046
# 2  0.040404  3.521643 -0.003084  0.017037  0.052715
# 3  0.060606  3.313708 -0.001269  0.002660  0.042855
# 4  0.080808  3.171802 -0.000605  0.000707  0.035594
# 5  0.101010  3.048322 -0.000317  0.000243  0.030396

# %% [markdown]
# # Make a transformation of the parameter

# %%
from mpl_toolkits import mplot3d
from IPython.display import clear_output

# %%
plt.plot(np.linspace(0, 1, 120), np.geomspace(.001, 2, 120))

# %%
num = 240
target = .3
top = 2
space = np.concatenate((target - np.geomspace(target, 0.00001, num//2), np.geomspace(target, top, num//2)))

plt.hexbin(space, [0 for y in np.linspace(0, 1, space.shape[0])], bins='log')

# %%
num = 240
target = .29
top = 2
space = np.concatenate(([0.0], target - np.geomspace(target, 0.00001, num//2), np.geomspace(target, top, num//2)[1:]))

k=0

for p in space:
    newdata = ilr_boxcox(data, p)
    
    fig, axs = plt.subplots(newdata.shape[1], newdata.shape[1], figsize=(15,12))

    for i in range(newdata.shape[1]):
        for j in range(newdata.shape[1]):
            if i==j:
                axs[i,j].set_yticklabels([])
                axs[i,j].set_xticklabels([])
                axs[i,j].get_xaxis().set_ticks([])
                axs[i,j].get_yaxis().set_ticks([])
                axs[i,j].text(y=.5, x=.5, s=round(p,3), 
                              ha='center', va='center', size=32)
                continue
            ax = axs[i, j].hexbin(x=newdata[:, i], y=newdata[:, j], bins='log', gridsize=50, cmap='inferno')

    fig.colorbar(ax, ax=axs.ravel().tolist(), orientation='vertical', shrink=1/(data.shape[1]+.5))
    plt.savefig("gif_plots/plt%d.png" %k)
    
    k+=1
    plt.close(fig)
    clear_output(wait=False)

# %%
import imageio
images = []
for angle in range(0, num):
    images.append(imageio.imread('gif_plots/plt%d.png' %angle))
imageio.mimsave('ilr_param_sweep_geom2.gif', images)

# %% [markdown]
# # 3d composition plots

# %%
from mpl_toolkits import mplot3d
from IPython.display import clear_output

# %%
n = 1000
D = 4

data2 = makeDirichletComposition(n, D)
# data2 = makeComposition(n, D)
# data2 = clr_boxcox(data2, 0.25)
data2 = ilr_boxcox(data2, .25)

# %%
# ax = plt.axes(projection='3d')

# Data for three-dimensional scattered points
xdata = data2[:, 0]
ydata = data2[:, 1]
zdata = data2[:, 2]

# ax.scatter3D(xdata, ydata, zdata, alpha=0.2, color='b')
# ax.view_init(30, 60)

# ax.set_xlabel('x')
# ax.set_ylabel('y')
# ax.set_zlabel('z')

# plt.show()


# rotate the axes and update
for angle in range(0, 360):
    ax = plt.axes(projection='3d')
    ax.scatter3D(xdata, ydata, zdata)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    
    ax.view_init(30, angle)
    plt.savefig("gif_plots/plt%d.png" %angle)
#     plt.pause(.0000000001)
    clear_output(wait=False);

# %%
import imageio
images = []
for angle in range(0, 360):
    images.append(imageio.imread('gif_plots/plt%d.png' %angle))
imageio.mimsave('ilr_boxcox_dirichlet3d_p25.gif', images)
